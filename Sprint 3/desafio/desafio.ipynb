# %% [markdown]
# #### Importando a biblioteca pandas

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# #### Abrindo o arquivo .csv

# %%
df_google=pd.read_csv('googleplaystore.csv')

# %% [markdown]
# #### Exibir no máximo 20 linhas do dataframe

# %%
pd.set_option('display.max_rows', 20)

# %% [markdown]
# #### "Df_google" é o nome do dataframe

# %%
df_google
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %% [markdown]
# #### Código para remoção das linhas duplicadas

# %%
df_google= df_google.drop_duplicates()

# %% [markdown]
# #### "Df_google" sem linhas duplicadas

# %%
df_google
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %% [markdown]
# #### Os 5 maiores aplicativos por números de instalação

# %%
# Converter a coluna 'Installs' para string
df_google.loc[:, 'Installs'] = df_google['Installs'].astype(str)

# Remover o valor 'Free', o símbolo '+' e as vírgulas
df_google.loc[:, 'Installs'] = df_google['Installs'].str.replace('Free', '', regex=False)
df_google.loc[:, 'Installs'] = df_google['Installs'].str.replace('+', '', regex=False)
df_google.loc[:, 'Installs'] = df_google['Installs'].str.replace(',', '', regex=False)

# Substituir strings vazias por pd.NA (sem precisar de NumPy)
df_google.loc[:, 'Installs'] = df_google['Installs'].replace('', pd.NA)

# Converter a coluna 'Installs' de string para float
df_google.loc[:, 'Installs'] = pd.to_numeric(df_google['Installs'], errors='coerce')

# Ordenar os aplicativos pela coluna 'Installs' em ordem decrescente e selecionar os 5 primeiros
top_5_apps = df_google.sort_values(by='Installs', ascending=False).head(5)

# Exibir os 5 melhores aplicativos com as colunas 'App' e 'Installs'
print(top_5_apps.loc[:, ['App', 'Installs']])
# Out:
#                                App      Installs
# 341                       Hangouts  1000000000.0
# 3928                       YouTube  1000000000.0
# 451                          Gmail  1000000000.0
# 3996  Google Chrome: Fast & Secure  1000000000.0
# 1700                Subway Surfers  1000000000.0

# %% [markdown]
# #### Representação gráfica em formato de barra dos 5 maiores aplicativos por número de instalação

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

print(top_5_apps[['App', 'Installs']])

plt.figure(figsize=(10, 6))

plt.bar(top_5_apps['App'], top_5_apps['Installs'], color=['blue', 'orange', 'green', 'red', 'purple'], width=0.4)

# Definir o rótulo do eixo Y
plt.ylabel('Número de Instalações')

plt.xlabel('Aplicativos')


plt.title('Top 5 Aplicativos por Número de Instalações')

plt.ylim(0, top_5_apps['Installs'].max() + 1000000)

plt.xticks(rotation=45)

ax = plt.gca()
ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: '{:,.0f}'.format(x)))

plt.tight_layout()

plt.show()
# Out:
#                                App      Installs
# 341                       Hangouts  1000000000.0
# 3928                       YouTube  1000000000.0
# 451                          Gmail  1000000000.0
# 3996  Google Chrome: Fast & Secure  1000000000.0
# 1700                Subway Surfers  1000000000.0

# %% [markdown]
# #### Contar quantos aplicativos existem em cada categoria

# %%
category_count = df_google['Category'].value_counts()
print(category_count)
# Out:
# Category
# FAMILY       1943
# GAME         1121
# TOOLS         843
# BUSINESS      427
# MEDICAL       408
#              ...
# EVENTS         64
# PARENTING      60
# COMICS         60
# BEAUTY         53
# 1.9             1
# Name: count, Length: 34, dtype: int64

# %% [markdown]
# #### Representação gráfica em formato de pizza para mostrar os aplicativos que existem em cada categoria

# %%
# Geração da contagem de categorias 
category_count = df_google['Category'].value_counts()

# Criar o gráfico de pizza sem os rótulos diretamente no gráfico
plt.figure(figsize=(10, 8))
plt.pie(category_count, autopct='%1.1f%%', startangle=140)

# Adicionar uma legenda com as categorias ao lado do gráfico
plt.legend(category_count.index, title="Categorias", loc="center left", bbox_to_anchor=(1, 0.5))

# Título e outras configurações
plt.title('Distribuição das Categorias de Aplicativos')
plt.axis('equal')  # Para garantir que o gráfico de pizza seja desenhado como um círculo
plt.tight_layout()  # Ajustar o layout para evitar cortes

# Mostrar o gráfico
plt.show()

# %% [markdown]
# #### Obter o aplicativo mais caro

# %%
# Converter a coluna 'Price' para string
df_google.loc[:, 'Price'] = df_google['Price'].astype(str)

# Remover o símbolo '$' e substituir 'Everyone' por '0', em seguida, converter para float
df_google.loc[:, 'Price'] = df_google['Price'].str.replace('$', '', regex=False)
df_google.loc[:, 'Price'] = df_google['Price'].str.replace('Everyone', '0', regex=False)
df_google.loc[:, 'Price'] = df_google['Price'].astype(float)

# Ordenar os aplicativos pela coluna 'Price' em ordem decrescente e selecionar o mais caro
mais_caro = df_google.sort_values(by='Price', ascending=False).head(1)

# Exibir o aplicativo mais caro com as colunas 'App' e 'Price'
print(mais_caro.loc[:, ['App', 'Price']])
# Out:
#                            App  Price
# 4367  I'm Rich - Trump Edition  400.0

# %% [markdown]
# ### Filtrando os aplicativos classificados como "Mature 17+"

# %%
mature_apps_count = df_google[df_google ['Content Rating'] == 'Mature 17+'].shape[0]

print(f"Total de apps classificados como 'Mature 17+': {mature_apps_count}")
# Out:
# Total de apps classificados como 'Mature 17+': 447

# %% [markdown]
# #### Filtrar os aplicativos com classificação "Mature 17+" e remover duplicatas na coluna "App"

# %%
mature_17 = df_google[df_google['Content Rating'] == 'Mature 17+'].drop_duplicates(subset='App')

# Contar o número de apps únicos com classificação "Mature 17+"
mature_17_count = mature_17.shape[0]

# Imprimir a contagem
print(mature_17_count)
# Out:
# 393

# %% [markdown]
# ####  Exibir o nome dos "Aplicativos" e o número de "Reviews"

# %%
# Converter 'Reviews' para numérico (inteiros ou flutuantes)
df_google.loc[:, 'Reviews'] = pd.to_numeric(df_google['Reviews'], errors='coerce')

# Verificar o tipo de dados da coluna 'Reviews'
print(df_google['Reviews'].dtype)  # Isso mostrará se é float64 ou int64

# Remover duplicatas com base no nome do aplicativo (coluna 'App')
df_google = df_google.drop_duplicates(subset='App', keep='first')

# Ordenar o DataFrame pelo número de reviews em ordem decrescente e selecionar os 10 primeiros
top_10_apps_reviews = df_google.sort_values(by='Reviews', ascending=False).head(10)

# Exibir o nome dos aplicativos e o número de reviews
print(top_10_apps_reviews.loc[:, ['App', 'Reviews']])
# Out:
# float64
#                                                     App     Reviews
# 2544                                           Facebook  78158306.0
# 336                                  WhatsApp Messenger  69119316.0
# 2545                                          Instagram  66577313.0
# 335            Messenger – Text and Video Chat for Free  56642847.0
# 1670                                     Clash of Clans  44891723.0
# 4005            Clean Master- Space Cleaner & Antivirus  42916526.0
# 1654                                     Subway Surfers  27722264.0
# 3665                                            YouTube  25655305.0
# 7536  Security Master - Antivirus, VPN, AppLock, Boo...  24900999.0
# 1660                                       Clash Royale  23133508.0

# %% [markdown]
# #### Obter os 10 mais gêneros frequentes

# %%
generos_mais_frequentes = df_google['Genres'].value_counts().head(10)
print(generos_mais_frequentes)
# Out:
# Genres
# Tools              826
# Entertainment      561
# Education          510
# Business           420
# Medical            395
# Personalization    376
# Productivity       374
# Lifestyle          368
# Finance            345
# Sports             331
# Name: count, dtype: int64

# %% [markdown]
# #### Representação gráfica em formato de linha dos 10 gêneros mais frequentes

# %%
plt.figure(figsize=(12, 6))  # Tamanho da figura
plt.plot(generos_mais_frequentes.index, generos_mais_frequentes.values, marker='o', color='b')
plt.title('Top 10 Gêneros de Aplicativos por Frequência', fontsize=14)
plt.xlabel('Gêneros', fontsize=12)
plt.ylabel('Contagem', fontsize=12)
plt.xticks(rotation=45, fontsize=10)  # Rotaciona os rótulos do eixo X
plt.grid()  # Adiciona grade para melhor visualização
plt.tight_layout()  # Ajusta o layout
plt.show()

# %% [markdown]
# #### Obter os tipos de contagem

# %%
tipo_contagem = df_google['Type'].value_counts()
print(tipo_contagem)
# Out:
# Type
# Free    8902
# Paid     756
# 0          1
# Name: count, dtype: int64

# %% [markdown]
# #### Representação gráfica em formato de barra dos tipos de contagem

# %%
plt.figure(figsize=(8, 6))
plt.bar(tipo_contagem.index, tipo_contagem.values, color=['skyblue', 'lightgreen'])
# Adicionar rótulos e título
plt.xlabel('Tipo de Aplicativo', fontsize=12)
plt.ylabel('Contagem', fontsize=12)
plt.title('Distribuição de Tipos de Aplicativos (Free vs Paid)', fontsize=14)

# Mostrar o gráfico
plt.show()
